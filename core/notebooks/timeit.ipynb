# %%
sg()
chapter_objects = ch.Chapter.objects(section=1).only('chapter', 'filename', 'html_path').to_json()
chapter_dicts = loads(chapter_objects)
pprint(chapter_dicts, indent=4)

# %%
# %%timeit
sg()
chapter_objects = ch.Chapter.objects(section=1).only('chapter', 'filename', 'html_path').to_json()
chapter_dicts = loads(chapter_object)[0]
pprint(chapter_dicts, indent=4)

# %%
# %%timeit
sg()
direct_results = {}
for doc in ch.Chapter.objects(section=1):
        chapter = doc.chapter
        filename = f"{doc.filename}.html"
        html_path = doc.html_path
        result = {
            "chapter": chapter,
            "filename": filename,
            "html_path": html_path}
        direct_results[chapter]=result
pprint(direct_results, indent=4)

# %% [markdown]
# # Default Doc Imports

# %% [markdown]
# try:
#     # < If run from main()
#     import core.book as book_
#     import core.chapter as ch
#     import core.endofbook as eob
#     import core.epubmetadata as epubmeta
#     import core.metadata as meta
#     import core.myaml as myaml
#     import core.section as sec
#     import core.titlepage as titlepg
#     from core.base import BASE, sg
#     from core.log import errwrap, log
#
# except ImportError:
#     # < If run from the core sub-directory
#     import book as book_
#     import chapter as ch
#     import endofbook as eob
#     import epubmetadata as epubmeta
#     import metadata as meta
#     import myaml
#     import section as sect
#     import titlepage as titlepg
#     from atlas import BASE, sg
#     from log import errwrap, log
#
#     # log.debug(f"Imported custom modules.")

# %% [markdown]
# # Epubmetadata Imports

# %%
# try:
#   from core.base import BASE, errwrap, max_title, sg
#   from core.book import Book
#   from core.log import log
#   import core.myaml as myaml
# except ImportError:
#   from atlas import BASE, errwrap, max_title, sg
#   from book import Book
#   from log import errwrap, log
#   import myaml

# %% [markdown]
# # Atlas Imports

# %%
# try:
#     from core.log import errwrap, log
# except ImportError:
#     from log import errwrap, log

# %% [markdown]
# # Book Imports

# %%
# try:
#     from core.base import BASE, max_title, sg
#     from core.log import errwrap, log
# except ImportError:
#     from atlas import BASE, max_title, sg
#     from log import errwrap, log

# %% [markdown]
# # Chapter Imports

# %%
# try:
#     from core.atlas import max_title, sg, mconnect
#     from core.log import errwrap, log
# except ImportError:
#     from atlas import max_title, sg, get_atlas_uri, BASE
#     from log import errwrap, lo

# %% [markdown]
# # Cover_MD Imports

# %%
# try:
#     from core.base import BASE, max_title, sg
#     from core.log import errwrap, log
# except ImportError:
#     from atlas import BASE, max_title, sg
#     from log import errwrap, log

# %% [markdown]
# # End of Book Imports

# %%
# try:
#     from core.base import BASE, max_title, sg
#     from core.book import Book
#     from core.log import errwrap, log
# except ImportError:
#     from atlas import BASE, max_title, sg
#     from book import Book
#     from log import errwrap, log

# %% [markdown]
# # Get_Chapter Imports

# %%
# try:
#     from core.atlas import sg, BASE
#     import core.chapter as chapter_
#     from sg310.SG import badWords, fixDemigod, geno_r, status, removeDotCom
# except ImportError:
#     from atlas import sg, BASE
#     import chapter as chapter_

# %% [markdown]
# # Metadata Imports

# %%
# try:
#     from core.base import BASE, errwrap, max_title, sg
#     from core.book import Book
#     from core.log import log, errwrap
#     import core.myaml as myaml
# except:
#     from atlas import BASE, max_title, sg
#     from book import Book
#     from log import errwrap, log
#     import myaml

# %% [markdown]
# # MYAML Imports

# %%
# try:
#     from core.base import BASE
#     from core.log import log
# except ImportError:
#     from atlas import BASE
#     from log import log

# %% [markdown]
# # Scrape Imports

# %%
# try:
#     import core.chapter as chapter_
#     from core.base import BASE, sg
#     from core.log import errwrap, log
#     from core.yay import finished
# except ImportError:
#     import chapter as chapter_
#     from atlas import BASE, sg
#     from log import errwrap, log
#     from yay import finished

# %% [markdown]
# # Section Imports

# %%
# try:
#     from core.base import BASE, max_title, sg
#     from core.log import errwrap, log
#     import core.book as book_
# except ImportError:
#     from atlas import BASE, max_title, sg
#     from log import errwrap, log
#     import book as book_

# %% [markdown]
# # Sort_JSON Imports

# %%
# try:
#     from core.atlas import max_title, sg
#     from core.chapter import Chapter
#     from core.log import errwrap, log
# except ImportError:
#     from atlas import max_title, sg
#     from chapter import Chapter
#     from log import errwrap, log

# %% [markdown]
# # Title Page Imports

# %%
# try:
#     from core.base import BASE, sg
#     from core.log import errwrap, log
# except ImportError:
#     from atlas import BASE, sg
#     from log import errwrap, log

# %% [markdown]
# # Yay Imports

# %%
# try:
#     from core.log import log, errwrap
# except ImportError:
#     from log import log, errwrap
